# %%
import nest_asyncio
import asyncio
import pandas as pd
from playwright.async_api import async_playwright
from bs4 import BeautifulSoup
import csv

# Apply the nested asyncio patch
nest_asyncio.apply()

async def scrape_details(url, page):
    try:
        # Navigate to the book page URL
        await page.goto(url)

        # Wait for necessary elements to load
        await page.wait_for_selector(".BookPageTitleSection__title", timeout=10000)

        # Extract the page content as HTML
        content = await page.content()

        # Parse the content with Beautiful Soup
        soup = BeautifulSoup(content, 'html.parser')

        # Extract book title
        title_element = soup.find('h1', class_='Text__title1')
        title = title_element.get_text(strip=True) if title_element else "N/A"

        # Extract author name
        author_element = soup.find('span', class_='ContributorLink__name')
        author = author_element.get_text(strip=True) if author_element else "N/A"

        # Extract genres (first three only)
        genre_elements = soup.select('span.BookPageMetadataSection__genreButton span.Button__labelItem')
        genres = [genre.get_text(strip=True) for genre in genre_elements[:3]]
        genre_text = ", ".join(genres) if genres else "N/A"



        return title, author, genre_text

    except Exception as e:
        print(f"Error scraping {url}: {e}")
    return "N/A", "N/A", "N/A"

async def main():
    # Read the URLs from the CSV file
    urls_df = pd.read_csv('books_with_ids.csv')
    urls_df = urls_df.drop_duplicates()  # Remove duplicate rows
    urls = urls_df['URL'].tolist()  # Replace 'url' with the actual column name in your CSV

    # Prepare CSV file to save results
    with open('scraped_details.csv', mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow(['URL', 'Title', 'Author', 'Genres'])

        async with async_playwright() as p:
            # Launch a browser
            browser = await p.chromium.launch(headless=False)  # Use headless=True to run without GUI
            context = await browser.new_context()
            page = await context.new_page()

            # Log in to Goodreads (use the correct URL and credentials as needed)
            await page.goto("https://www.goodreads.com/ap/signin?language=en_US&openid.assoc_handle=amzn_goodreads_web_na&openid.claimed_id=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&openid.identity=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&openid.mode=checkid_setup&openid.ns=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0&openid.pape.max_auth_age=0&openid.return_to=https%3A%2F%2Fwww.goodreads.com%2Fap-handler%2Fsign-in&siteState=eyJyZXR1cm5fdXJsIjoiaHR0cHM6Ly93d3cuZ29vZHJlYWRzLmNvbS8ifQ%3D%3D")
            await page.wait_for_selector("input[name='email']", timeout=5000)
            await page.fill("input[name='email']", "robiulriyadh66@gmail.com")  # Replace with your email
            await page.fill("input[name='password']", "V!MZUhP8TL39-jH")        # Replace with your password
            await page.click("input[type='submit']")
            await page.wait_for_selector(".siteHeader__topLevelLink", timeout=30000)

            # Iterate over each URL and scrape details
            for url in urls:
                title, author, genres = await scrape_details(url, page)
                writer.writerow([url, title, author, genres])
                print(f"Scraped {url}: Title: {title}, Author: {author}, Genres: {genres}")

            # Close the browser
            await browser.close()

# Run the async function
await main()
# Out:
# Scraped https://www.goodreads.com/book/show/617097.Pather_Panchali: Title: Pather Panchali: Song of the Road, Author: Bibhutibhushan Bandyopadhyay, Genres: Fiction, Classics, India
# Scraped https://www.goodreads.com/book/show/7936528: Title: চাঁদের পাহাড়, Author: Bibhutibhushan Bandyopadhyay, Genres: Adventure, Fiction, Classics
# Scraped https://www.goodreads.com/book/show/2426848._: Title: ব্যোমকেশ সমগ্র, Author: Sharadindu Bandyopadhyay, Genres: Detective, Mystery, Fiction
# Scraped https://www.goodreads.com/book/show/244524.The_Complete_Adventures_of_Feluda_Vol_1: Title: The Complete Adventures of Feluda, Vol. 1, Author: Satyajit Ray, Genres: Mystery, Fiction, Detective
# Scraped https://www.goodreads.com/book/show/1268536.Sesher_Kobita_the_Last_Poem: Title: Sesher Kobita, the Last Poem, Author: Rabindranath Tagore, Genres: Fiction, Romance, Classics
# Scraped https://www.goodreads.com/book/show/670686._: Title: শঙ্কু সমগ্র, Author: Satyajit Ray, Genres: Science Fiction, Adventure, Fiction
# Scraped https://www.goodreads.com/book/show/3084276: Title: আরণ্যক, Author: Bibhutibhushan Bandyopadhyay, Genres: Fiction, Classics, Novels
# Scraped https://www.goodreads.com/book/show/33917.The_Namesake: Title: The Namesake, Author: Jhumpa Lahiri, Genres: Fiction, Literary Fiction, Contemporary
# Scraped https://www.goodreads.com/book/show/11590099: Title: টেনিদা সমগ্র, Author: Narayan Gangopadhyay, Genres: Comedy, Humor, Fiction
# Scraped https://www.goodreads.com/book/show/244526.The_Complete_Adventures_of_Feluda_Vol_2: Title: The Complete Adventures of Feluda, Vol. 2, Author: Satyajit Ray, Genres: Mystery, Fiction, Detective
# Scraped https://www.goodreads.com/book/show/15841419: Title: গল্পগুচ্ছ, Author: Rabindranath Tagore, Genres: Short Stories, Classics, Fiction
# Scraped https://www.goodreads.com/book/show/10290924: Title: সেই সময়, Author: Sunil Gangopadhyay, Genres: Historical Fiction, Fiction, India
# Scraped https://www.goodreads.com/book/show/10416071: Title: বিশ্বাসঘাতক, Author: Narayan Sanyal, Genres: Nonfiction, Thriller, History
# Scraped https://www.goodreads.com/book/show/1417962.Srikanta: Title: Srikanta, Author: Sarat Chandra Chattopadhyay, Genres: Fiction, Classics, India
# Scraped https://www.goodreads.com/book/show/14759169: Title: শঙ্খনীল কারাগার, Author: Humayun Ahmed, Genres: Fiction, Novels, Drama
# Scraped https://www.goodreads.com/book/show/1247393.Abol_Tabol: Title: Abol Tabol: The Nonsense World of Sukumar Ray, Author: Sukumar Ray, Genres: Poetry, Classics, Childrens
# Scraped https://www.goodreads.com/book/show/1268541.Gora: Title: Gora, Author: Rabindranath Tagore, Genres: Fiction, India, Classics
# Scraped https://www.goodreads.com/book/show/13422478: Title: কাবুলিওয়ালা, Author: Rabindranath Tagore, Genres: Short Stories, Classics, Fiction
# Scraped https://www.goodreads.com/book/show/13241511: Title: কালবেলা, Author: Samaresh Majumdar, Genres: Fiction, Novels, Historical Fiction
# Scraped https://www.goodreads.com/book/show/262038.Mother_of_1084: Title: Mother of 1084, Author: Mahasweta Devi, Genres: Fiction, India, Historical Fiction
# Scraped https://www.goodreads.com/book/show/13606504: Title: প্রথম আলো ১, Author: Sunil Gangopadhyay, Genres: Historical Fiction, Historical, Classics
# Scraped https://www.goodreads.com/book/show/5273533: Title: দেবী, Author: Humayun Ahmed, Genres: Fiction, Horror, Mystery
# Scraped https://www.goodreads.com/book/show/12733425: Title: কাকাবাবু সমগ্র ১, Author: Sunil Gangopadhyay, Genres: Adventure, Detective, Mystery
# Scraped https://www.goodreads.com/book/show/258497.Devdas: Title: Devdas, Author: Sarat Chandra Chattopadhyay, Genres: Fiction, Classics, Romance
# Scraped https://www.goodreads.com/book/show/13425917: Title: গল্প ১০১, Author: Satyajit Ray, Genres: Short Stories, Fiction, Horror
# Scraped https://www.goodreads.com/book/show/12359912: Title: ময়ূরাক্ষী, Author: Humayun Ahmed, Genres: Fiction, Novels, Drama
# Scraped https://www.goodreads.com/book/show/115030.Chokher_Bali: Title: Chokher Bali, Author: Rabindranath Tagore, Genres: Fiction, Classics, India
# Scraped https://www.goodreads.com/book/show/1074682.Chowringhee: Title: Chowringhee, Author: Sankar, Genres: Fiction, India, Classics
# Scraped https://www.goodreads.com/book/show/17673148: Title: পদ্মানদীর মাঝি, Author: Manik Bandopadhyay, Genres: Fiction, Classics, Novels
# Scraped https://www.goodreads.com/book/show/13498513: Title: পুতুলনাচের ইতিকথা, Author: Manik Bandopadhyay, Genres: Fiction, Classics, Novels
# Scraped https://www.goodreads.com/book/show/66414.Gitanjali: Title: Gitanjali, Author: Rabindranath Tagore, Genres: Poetry, Classics, India
# Scraped https://www.goodreads.com/book/show/258529.Parineeta: Title: Parineeta, Author: Sarat Chandra Chattopadhyay, Genres: Classics, Romance, Fiction
# Scraped https://www.goodreads.com/book/show/14741940: Title: আদর্শ হিন্দু হোটেল, Author: Bibhutibhushan Bandyopadhyay, Genres: Fiction, Classics, Novels
# Scraped https://www.goodreads.com/book/show/16143698: Title: ঠাকু'মার ঝুলি, Author: Dakshinaranjan Mitra Majumder, Genres: Fantasy, Childrens, Classics
# Scraped https://www.goodreads.com/book/show/17201869: Title: উত্তরাধিকার, Author: Samaresh Majumdar, Genres: Fiction, Novels, Historical Fiction
# Scraped https://www.goodreads.com/book/show/1338762._: Title: কলকাতায় ফেলুদা, Author: Satyajit Ray, Genres: Mystery, Detective, Thriller
# Scraped https://www.goodreads.com/book/show/9255439: Title: দীপু নাম্বার টু, Author: Muhammed Zafar Iqbal, Genres: Fiction, Adventure, Young Adult
# Scraped https://www.goodreads.com/book/show/13454987: Title: কালপুরুষ, Author: Samaresh Majumdar, Genres: Fiction, Novels, Drama
# Scraped https://www.goodreads.com/book/show/15720202: Title: মনোজদের অদ্ভুত বাড়ি, Author: Shirshendu Mukhopadhyay, Genres: Fiction, Humor, Fantasy
# Scraped https://www.goodreads.com/book/show/15824406: Title: হাজার বছর ধরে, Author: Zahir Raihan, Genres: Fiction, Classics, Novels
# Scraped https://www.goodreads.com/book/show/11589378: Title: প্রথম আলো ২, Author: Sunil Gangopadhyaya, Genres: Historical Fiction, Fiction, Novels
# Scraped https://www.goodreads.com/book/show/17458632: Title: নন্দিত নরকে, Author: Humayun Ahmed, Genres: Fiction, Novels, Drama
# Scraped https://www.goodreads.com/book/show/85301.Unaccustomed_Earth: Title: Unaccustomed Earth, Author: Jhumpa Lahiri, Genres: Fiction, Short Stories, India
# Scraped https://www.goodreads.com/book/show/5439.Interpreter_of_Maladies: Title: Interpreter of Maladies, Author: Jhumpa Lahiri, Genres: Short Stories, Fiction, India
# Scraped https://www.goodreads.com/book/show/8547493: Title: নিশীথিনী, Author: Humayun Ahmed, Genres: Fiction, Horror, Mystery
# Scraped https://www.goodreads.com/book/show/1791895.Anandamath: Title: Anandamath, Author: Bankim Chandra Chattopadhyay, Genres: Fiction, India, Classics
# Scraped https://www.goodreads.com/book/show/2381078.Pather_Dabi: Title: Pather Dabi: The Right of Way, Author: Sarat Chandra Chattopadhyay, Genres: Fiction, Classics, Novels
# Scraped https://www.goodreads.com/book/show/3895926: Title: দেবী চৌধুরানী, Author: Bankim Chandra Chattopadhyay, Genres: Fiction, Classics, Historical Fiction
# Scraped https://www.goodreads.com/book/show/6422836: Title: দেশে বিদেশে, Author: Syed Mujtaba Ali, Genres: Travel, Nonfiction, History
# Scraped https://www.goodreads.com/book/show/174216.The_Home_and_the_World: Title: The Home and the World, Author: Rabindranath Tagore, Genres: Fiction, Classics, India
