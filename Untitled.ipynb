# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Load the CSV file containing the User IDs and URLs
df_csv = pd.read_csv('User_Review_url_and_ID.csv')

# Headers to simulate a browser
headers = {
    "accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,/;q=0.8,application/signed-exchange;v=b3;q=0.7",
    "accept-language": "en-US,en;q=0.9",
    "cache-control": "max-age=0",
    "cookie": 'ccsid=997-0059822-9974992; locale=en; blocking_sign_in_interstitial=true; csm-sid=448-9044706-8238887; session-id=138-9449735-4650719; lc-main=en_US; ubid-main=132-0831767-7645715; csm-hit=tb:s-HH6TEBC541XWDPX2HW08|1728400665806&t:1728400665807; session-id-time=2359120669l; session-token=""; x-main="qY09NsWCzSNW8b933Yonj4af6qs5TDB0DUsYapgS18@nyKFkHdJj5p@Mt2dldE6F"; at-main=Atza|IwEBIKKe6dZi9mkGtv2CtS3qsv9NuaJNSNpmNpDSxRXvt17a_x2-zjEpiAOHkEQ34JuOVngoGfAl8dIqliYqOigT30w9CGWKtZI6rgDWz0mruXs-yNgr_nsxBWgaXid-1e8ZvmgQryKo5OgAIx-Lce0ocNWWSfh3g77KeZNETFdonWPAuJz5V82UuuKblmr-o03ZzeyBC7rbWUbFLRhtcSWy7Mqogs8ONE5dM3XgdBITj5b5F2h4Z_ih2WgCM4wTps3r6HY; sess-at-main="l6swvzfG2thASaG98K8Nu/j0D/+teOfY5a1UhpsZBz8="; likely_has_account=true; *session*id2=4cd4cabfc8c16e891c0f62348aa076dd',
    "if-none-match": 'W/"862d60fdc6915eed33d69a373690f36d"',
    "priority": "u=0, i",
    "sec-ch-ua": '"Google Chrome";v="129", "Not=A?Brand";v="8", "Chromium";v="129"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "document",
    "sec-fetch-mode": "navigate",
    "sec-fetch-site": "none",
    "sec-fetch-user": "?1",
    "upgrade-insecure-requests": "1",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36"
}

# Initialize a DataFrame to store ratings
ratings_data = []
cnt = 0  # Global counter to track the total iterations

# Iterate through each User_ID in the CSV file
for index, row in df_csv.iterrows():
    user_id = row['User_ID']
    print(f"Processing User ID: {user_id}")
    
    for i in range(1, 2):  # Loop through pages if needed, modify the range accordingly
        print(f"Scraping page {i}")
        url = f"https://www.goodreads.com/review/list/{user_id}?order=d&page={i}&sort=rating&view=reviews"
        print(f"Scraping URL: {url}")
        
        # Request the page
        response = requests.get(url, headers=headers)
        
        # Parse the content with BeautifulSoup
        soup = BeautifulSoup(response.content, 'html.parser')

        # Find all rows in the table where book ID and rating are stored
        rows = soup.find_all('tr', class_='bookalike review')

        for row in rows:
            # Step 1: Find the <td> with the book ID in the link
            book_td = row.find('td', class_='field title')
            if book_td:
                bb = book_td.find('div', class_='value')
                a_tag = bb.find('a', href=True)
                if a_tag and '/book/show/' in a_tag['href']:
                    book_url = a_tag['href']
                    book_id = book_url.split('/book/show/')[1].split('-')[0].split('.')[0]
                    
                    # Step 2: Find the <td> with the rating (sibling or close td)
                    rating_td = row.find('td', class_='field rating')
                    if rating_td:
                        stars = rating_td.find_all('span', class_='staticStar p10')
                        rating = len(stars)

                        # Append the data to the list
                        ratings_data.append({
                            'User_ID': user_id,
                            'Book_ID': book_id,
                            'Rating': rating
                        })
                        
                        cnt += 1  # Increment the counter
                        if cnt >= 1000:  # Stop the process once we reach 10 iterations
                            break

        if cnt >= 1000:  # Break out of outer loop if cnt >= 10
            break
    if cnt >= 1000:  # Break out of the user ID loop if cnt >= 10
        break

# Convert to DataFrame
ratings_df = pd.DataFrame(ratings_data)

# Display the DataFrame
print(ratings_df)

# Optionally, save to a CSV file
ratings_df.to_csv('scraped_ratings.csv', index=False)
# Out:
# Processing User ID: 14008088
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/14008088?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 107704225
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/107704225?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 87324
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/87324?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 24175715
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/24175715?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 148958882
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/148958882?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 2736147
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/2736147?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 107928784
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/107928784?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 151393802
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/151393802?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 152995429
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/152995429?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 94815246
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/94815246?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 19703758
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/19703758?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 97513431
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/97513431?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 54651494
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/54651494?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 57123230
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/57123230?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 99185905
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/99185905?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 12508032
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/12508032?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 119107935
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/119107935?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 145078410
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/145078410?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 3654176
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/3654176?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 23621066
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/23621066?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 9100524
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/9100524?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 17834354
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/17834354?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 96554247
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/96554247?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 43652633
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/43652633?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 111488640
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/111488640?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 93841856
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/93841856?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 102486020
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/102486020?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 74773503
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/74773503?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 4469709
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/4469709?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 1597717
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/1597717?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 13091599
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/13091599?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 73221135
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/73221135?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 108499989
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/108499989?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 21786051
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/21786051?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 147579391
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/147579391?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 56068189
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/56068189?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 65574059
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/65574059?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 151393802
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/151393802?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 53105643
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/53105643?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 93203716
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/93203716?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 103293496
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/103293496?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 43309961
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/43309961?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 44191110
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/44191110?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 10051075
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/10051075?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 2736147
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/2736147?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 87149498
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/87149498?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 46735809
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/46735809?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 43652633
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/43652633?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 20310470
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/20310470?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 55614051
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/55614051?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 97513431
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/97513431?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 107928784
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/107928784?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 2989677
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/2989677?order=d&page=1&sort=rating&view=reviews
# Processing User ID: 122953955
# Scraping page 1
# Scraping URL: https://www.goodreads.com/review/list/122953955?order=d&page=1&sort=rating&view=reviews
#        User_ID  Book_ID  Rating
# 0     14008088    14116       5
# 1     14008088    14118       5
# 2     14008088    24812       5
# 3     14008088    72915       5
# 4     14008088    72910       5
# ..         ...      ...     ...
# 995  122953955  2426632       5
# 996  122953955    52529       5
# 997  122953955   157993       5
# 998  122953955        5       5
# 999  122953955   687278       5
#
# [1000 rows x 3 columns]
